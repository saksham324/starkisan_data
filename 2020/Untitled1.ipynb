# %%
import pandas as pd 
import camelot

# %%
list = ['2020/01012020.pdf',
         '2020/02012020.pdf',
         '2020/03012019.pdf',
         '2020/04012020.pdf',
         '2020/06012020.pdf',
         '2020/07012020.pdf',
         '2020/08012020.pdf',
         '2020/09012020.pdf',
         '2020/10012020.pdf',
         '2020/11012020.pdf',
         '2020/13012020.pdf',
         '2020/14012020.pdf',
         '2020/15012020.pdf',
         '2020/16012020.pdf',
         '2020/17012020.pdf',
         '2020/18012020.pdf',
         '2020/20012020.pdf',
         '2020/21012020.pdf',
         '2020/22012020.pdf',
         '2020/23012020.pdf',
         '2020/24012020.pdf',
         '2020/25012020.pdf',
         '2020/27012020.pdf',
         '2020/28012020.pdf',
         '2020/29012020.pdf',
         '2020/30012020.pdf',
         '2020/31012020.pdf',
         '2020/01022020.pdf',
         '2020/03022020.pdf',
         '2020/04022020.pdf',
         '2020/05022020.pdf',
         '2020/06022020.pdf',
         '2020/07022020.pdf',
         '2020/09022020.pdf',
         '2020/10022020.pdf',
         '2020/11022020.pdf',
         '2020/12022020.pdf',
         '2020/13022020.pdf',
         '2020/14022020.pdf',
         '2020/15022020.pdf',
         '2020/17022020.pdf',
         '2020/18022020.pdf',
         '2020/19022020.pdf',
         '2020/20022020.pdf',
         '2020/21022020.pdf',
         '2020/22022020',
         '2020/24022020.pdf',
         '2020/25022020.pdf',
         '2020/26022020.pdf',
         '2020/27022020.pdf',
         '2020/28022020.pdf',
         '2020/29022020.pdf',
         '2020/02032020.pdf',
         '2020/03032020.pdf',
         '2020/04032020.pdf',
         '2020/05032020.pdf',
         '2020/06032020.pdf',
         '2020/07032020.pdf',
         '2020/09032020.pdf',
         '2020/11032020.pdf',
         '2020/12022020.pdf',
         '2020/13032020.pdf',
         '2020/14032020.pdf',
         '2020/16032020.pdf',
         '2020/17032020.pdf',
         '2020/18032020.pdf',
         '2020/19032020.pdf',
         '2020/20032020.pdf',
         '2020/21032020.pdf',
         '2020/23032020.pdf',
         '2020/24032020.pdf',
         '2020/25032020.pdf',
         '2020/26032020.pdf',
         '2020/27032020.pdf',
         '2020/28032020.PDF',
         '2020/30032020.pdf',
         '2020/31032020.pdf',
         '2020/01042020.pdf',
         '2020/02042020.pdf',
         '2020/03042020.pdf',
         '2020/04042020.pdf',
         '2020/06042020.pdf',
         '2020/07042020.pdf',
         '2020/08042020.pdf',
         '2020/09042020.pdf',
         '2020/10042020.pdf',
         '2020/11042020.pdf',
         '2020/13042020.pdf',
         '2020/14042020.pdf',
         '2020/15042020.pdf',
         '2020/16042020.pdf',
         '2020/17042020.pdf',
         '2020/18042020.PDF',
         '2020/20042020.pdf',
         '2020/21042020.pdf',
         '2020/22042020.pdf',
         '2020/23042020.pdf',
         '2020/24042020.pdf',
         '2020/25042020.pdf',
         '2020/27042020.pdf',
         '2020/28042020.pdf',
         '2020/28042020.pdf',
         '2020/30042020.pdf',
         '2020/01052020.pdf',
         '2020/02052020.pdf',
         '2020/04052020.pdf',
         '2020/05052020.pdf',
         '2020/06052020.pdf',
         '2020/07052020.pdf',
         '2020/08052020.PDF',
         '2020/09052020.pdf',
         '2020/11052020.pdf',
         '2020/12052020.pdf',
         '2020/13052020.pdf',
         '2020/14052020.pdf',
         '2020/15052020.pdf',
         '2020/16/05/2020.pdf',
         '2020/18052020.pdf',
         '2020/19052020.pdf',
         '2020/20052020.pdf',
         '2020/21052020.pdf',
         '2020/22052020.pdf',
         '2020/23052020.pdf',
         '2020/25052020.pdf',
         '2020/26052020.pdf',
         '2020/27052020.pdf',
         '2020/28052020.pdf',
         '2020/29052020.pdf',
         '2020/30052020.pdf',
         '2020/01062020.pdf',
         '2020/02062020.pdf',
         '2020/03062020.pdf',
         '2020/04062020.pdf',
         '2020/05062020.pdf',
         '2020/06062020.pdf',
         '2020/08062020.pdf',
         '2020/09062020.pdf',
         '2020/10062020.pdf',
         '2020/11062020.pdf',
         '2020/12062020.pdf',
         '2020/13062020.pdf',
         '2020/15062020.pdf',
         '2020/16062020.pdf',
         '2020/17062020.pdf',
         '2020/18062020.pdf',
         '2020/19062020.pdf',
         '2020/20062020.pdf',
         '2020/22062020.pdf',
         '2020/23062020.pdf',
         '2020/24062020.pdf',
         '2020/25062020.pdf',
         '2020/26062020.pdf',
         '2020/27062020.pdf',
         '2020/29062020.pdf',
         '2020/30062020.pdf',
         '2020/01072020.pdf',
         '2020/02072020.pdf',
         '2020/03072020.pdf',
         '2020/04072020.pdf',
         '2020/06072020.pdf',
         '2020/07072020.pdf',
         '2020/08072020.pdf',
         '2020/09072020.pdf',
         '2020/10072020.pdf',
         '2020/11072020.pdf',
         '2020/13072020.pdf',
         '2020/14072020.pdf']

# %%
for item in list:
    print(item)
    tables = camelot.read_pdf(item[5:])
#     df = tables[0].df
#     df = df[2:]
#     for i in range(1, 7):
#         df1 = tables[i].df
#         df1 = df1[2:]
#         df = pd.concat([df,df1], axis=0)
# Out:
# 2020/01012020.pdf
# ---------------------------------------------------------------------------
# GhostscriptError                          Traceback (most recent call last)
# <ipython-input-6-8164ce4cd24e> in <module>
#       1 for item in list:
#       2     print(item)
# ----> 3     tables = camelot.read_pdf(item[5:])
#       4 #     df = tables[0].df
#       5 #     df = df[2:]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     115             suppress_stdout=suppress_stdout,
#     116             layout_kwargs=layout_kwargs,
# --> 117             **kwargs
#     118         )
#     119         return tables
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/handlers.py in parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     170             for p in pages:
#     171                 t = parser.extract_tables(
# ...
