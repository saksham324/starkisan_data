         '2019/28012019.pdf',
         '2019/29012019.pdf',
         '2019/30012019.pdf',
         '2019/31012019.pdf',
         '2019/01022019.pdf',
         '2019/02022019.pdf',
         '2019/04022019.pdf',
         '2019/05022019.pdf',
         '2019/06022019.pdf',
         '2019/07022019.pdf',
         '2019/08022019.pdf',
         '2019/09022019.pdf',
         '2019/11022019.pdf',
         '2019/12022019.pdf',
         '2019/13022019.pdf',
         '2019/14022019.pdf',
         '2019/15022019.pdf',
         '2019/16022019.pdf',
         '2019/18022019.pdf',
         '2019/19022019.pdf',
         '2019/20022019.pdf',
         '2019/21022019.pdf',
         '2019/22022019.pdf',
         '2019/23022019.pdf',
         '2019/25022019.pdf',
         '2019/26022019.pdf',
         '2019/27022019.pdf',
         '2019/28022019.pdf',
         '2019/01032019.pdf',
         '2019/02032019.pdf',
         '2019/04032019.pdf',
         '2019/05032019.pdf',
         '2019/06032019.PDF',
         '2019/07022019.pdf',
         '2019/08032019.pdf',
         '2019/09032019.pdf',
         '2019/11032019.pdf',
         '2019/12032019.pdf',
         '2019/13032019.pdf',
         '2019/14032019.pdf',
         '2019/15032019.pdf',
         '2019/16032019.pdf/',
         '2019/18032019.pdf',
         '2019/19032019.pdf',
         '2019/20032019.pdf',
         '2019/22032019.pdf',
         '2019/23032019.pdf',
         '2019/25022019.pdf',
         '2019/26032019.pdf',
         '2019/27032019.pdf',
         '2019/28032019.pdf',
         '2019/29032019.pdf',
         '2019/30032019.pdf',
         '2019/01042019.pdf',
         '2019/02042019.PDF',
         '2019/03042019.PDF',
         '2019/04042019.pdf',
         '2019/05042019.pdf',
         '2019/06042019.pdf',
         '2019/08042019.pdf',
         '2019/09042019.pdf',
         '2019/10042019.pdf',
         '2019/11042019.pdf',
         '2019/12042019.pdf',
         '2019/13042019.pdf',
         '2019/15042019.pdf',
         '2019/16042019.pdf',
         '2019/17042019.pdf',
         '2019/18042019.pdf',
         '2019/19042019.pdf',
         '2019/20042019.pdf',
         '2019/22042019.pdf',
         '2019/23042019.pdf',
         '2019/24042019.pdf',
         '2019/25042019.pdf',
         '2019/26042019.pdf',
         '2019/27042019.pdf',
         '2019/29042019.pdf',
         '2019/30042019.pdf',
         '2019/01052019.pdf',
         '2019/02052019.pdf',
         '2019/03052019.pdf',
         '2019/04052019.pdf',
         '2019/06052019.pdf',
         '2019/07052019.pdf',
         '2019/08052019.pdf',
         '2019/09052019.pdf',
         '2019/10052019.pdf',
         '2019/11052019.pdf',
         '2019/13052019.pdf',
         '2019/14052019.pdf',
         '2019/15052019.pdf',
         '2019/16052019.pdf',
         '2019/17052019.pdf',
         '2019/18052019.pdf',
         '2019/20052019.pdf',
         '2019/21052019.pdf',
         '2019/22052019.pdf',
         '2019/23052019.pdf',
         '2019/24052019.pdf',
         '2019/25052019.pdf',
         '2019/27052019.pdf',
         '2019/28052019.pdf',
         '2019/29052019.pdf',
         '2019/30052019.pdf',
         '2019/31052019.pdf',
         '2019/01062019.pdf',
         '2019/03062019.pdf',
         '2019/04062019.pdf',
         '2019/05062019.pdf',
         '2019/06062019.pdf',
         '2019/07062019.pdf',
         '2019/08062019.pdf',
         '2019/10062019.pdf',
         '2019/11062019.pdf',
         '2019/12062019.pdf',
         '2019/13062019.pdf',
         '2019/14062019.pdf',
         '2019/15062019.pdf',
         '2019/17062019.pdf',
         '2019/18062019.pdf',
         '2019/19062019.pdf',
         '2019/20062019.pdf',
         '2019/21062019.pdf',
         '2019/22062019.pdf',
         '2019/24062019.pdf',
         '2019/25062019.pdf',
         '2019/26062019.pdf',
         '2019/27062019.pdf',
         '2019/28062019.pdf',
         '2019/29062019.pdf',
         '2019/01072019.pdf',
         '2019/02072019.pdf',
         '2019/03072019.pdf',
         '2019/04072019.pdf',
         '2019/05072019.pdf',
         '2019/06072019.pdf',
         '2019/08072019.pdf',
         '2019/09072019.pdf',
         '2019/10072019.pdf',
         '2019/11072019.pdf',
         '2019/12072019.pdf',
         '2019/13072019.pdf',
         '2019/15072019.pdf',
         '2019/16072019.pdf',
         '2019/17072019.pdf',
         '2019/18072019.pdf',
         '2019/19072019.pdf',
         '2019/20072019.pdf',
         '2019/22072019.pdf',
         '2019/23072019.pdf',
         '2019/24072019.pdf',
         '2019/25072019.pdf',
         '2019/26072019.pdf',
         '2019/27072019.pdf',
         '2019/29072019.pdf',
         '30072019.pdf',
         '2019/31072019.pdf',
         '2019/01082019.pdf',
         '2019/02082019.pdf',
         '2019/03082019.pdf',
         '2019/05082019.pdf',
         '2019/06082019.pdf',
         '2019/07082019.pdf',
         '2019/08082019.pdf',
         '2019/09082019.pdf',
         '2019/10082019.pdf',
         '2019/12082019.pdf',
         '2019/13082019.pdf',
         '2019/14082019.pdf',
         '2019/16082019.pdf',
         '2019/17082019.pdf',
         '2019/19082019.pdf',
         '2019/20082019.pdf',
         '2019/21082019.pdf',
         '2019/22082019.pdf',
         '2019/23082019.pdf',
         '2019/24092019.pdf',
         '2019/26092019.pdf',
         '2019/27082019.PDF',
         '2019/28082019.pdf',
         '2019.29082019.pdf',
         '2019/30082019.pdf',
         '2019/31082019.pdf',
         '2019/02092019.pdf',
         '2019/03092019.pdf',
         '2019/04092019.pdf',
         '2019/05092019.pdf',
         '2019/06092019.pdf',
         '2019/07092019.pdf',
         '2019/09092019.pdf',
         '2019/10092019.pdf',
         '2019/11092019.pdf',
         '2019/12092019.pdf',
         '2019/13092019.pdf',
         '2019/14092019.pdf',
         '2019/16092019.pdf',
         '2019/17092019.pdf',
         '2019/18092019.pdf',
         '2019/19092019.pdf',
         '2019/20092019.pdf',
         '2019/21092019.pdf',
         '2019/23092019.pdf',
         '2019/24092019.pdf',
         '2019/25092019.pdf',
         '2019/26092019.pdf',
         '2019/27092019.pdf',
         '2019/28092019.pdf',
         '2019/30092019.pdf',
         '2019/01102019.pdf',
         '2019/03102019.pdf',
         '2019/04102019.pdf',
         '2019/02102019.pdf',
         '2019/07102019.pdf',
         '2019/08102019.pdf',
         '2019/09102019.pdf',
         '2019/10102019.pdf',
         '2019/11102019.pdf',
         '2019/12102019.pdf',
         '2019/14102019.pdf',
         '2019/15102019.pdf',
         '2019/16102019.PDF',
 '2018/14112018.pdf',
 '2018/15112018.pdf',
 '2018/16112018.pdf',
 '2018/17112018.pdf',
 '2018/19112018.pdf',
 '2018/20112018.pdf',
 '2018/21112018.pdf',
 '2018/22112018.pdf',
 '2018/23112018.pdf',
 '2018/24112018.pdf',
 '2018/26112018.pdf',
 '2018/27112018.pdf',
 '2018/28112018.pdf',
 '2018/29112018.pdf',
 '2018/30112018.pdf',
 '2018/01122018.pdf',
 '2018/03122018.pdf',
 '2018/04122018.PDF',
 '2018/05122018.pdf',
 '2018/06122018.pdf',
 '2018/07122018.pdf',
 '2018/08122018.pdf',
 '2018/10122018.pdf',
 '2018/11122018.pdf',
 '2018/12122018.pdf',
 '2018/13122018.pdf',
 '2018/14122018.pdf',
 '2018/15122018.pdf',
 '2018/17122018.pdf',
 '2018/18122018.pdf',
 '2018/19122018.pdf',
 '2018/20122018.pdf',
 '2018/21122018.pdf',
 '2018/22122018.pdf',
 '2018/24122018.pdf',
 '2018/25122018.pdf',
 '2018/26122018.pdf',
 '2018/27122018.pdf',
 '2018/28122018.pdf',
 '2018/29122018.pdf',
 '2018/31122018.pdf']
list_2018 = [item for item in list_2018 if item[7:9] == "06"]

# %%
list_2019
# Out:
# ['2019/01062019.pdf',
#  '2019/03062019.pdf',
#  '2019/04062019.pdf',
#  '2019/05062019.pdf',
#  '2019/06062019.pdf',
#  '2019/07062019.pdf',
#  '2019/08062019.pdf',
#  '2019/10062019.pdf',
#  '2019/11062019.pdf',
#  '2019/12062019.pdf',
#  '2019/13062019.pdf',
#  '2019/14062019.pdf',
#  '2019/15062019.pdf',
#  '2019/17062019.pdf',
#  '2019/18062019.pdf',
#  '2019/19062019.pdf',
#  '2019/20062019.pdf',
#  '2019/21062019.pdf',
#  '2019/22062019.pdf',
#  '2019/24062019.pdf',
#  '2019/25062019.pdf',
#  '2019/26062019.pdf',
#  '2019/27062019.pdf',
#  '2019/28062019.pdf',
#  '2019/29062019.pdf']

# %%
import pandas as pd
import numpy as np 
import camelot

# %%
tables = camelot.read_pdf("2018/30062018.pdf", pages="all")

# %%
dff = tables[3].df
dff
# Out:
#                     0                           1        2            3  \
# 0                  Sl                 NAME OF THE  ARRIVAL      VARIETY
# 1   NO. COMM. & STATE                              IN TONS
# 2
# 3
# 4                   1                      POTATO   1030.8
# ..                ...                         ...      ...          ...
# 67
# 68                 19                      CHOLAI      3.5
# 69                                            LOC
# 70                 20                    CUCUMBER    197.1
# 71                     UP/KANPUR/HR/RAJ/WB/RAIPUR           DESI/RAIPUR
#
#                    4         5 6       7                 8     9     10
# 0   WEIGHT \nTYPE OF               GRADE  Wholesale Prices
# 1    IN KG.\nPACKING                SIZE              MINI  MAXI  MODAL
# 2        1\nKG LOOSE                   B                 4     6      5
# 3         VEGETABLES
# 4
# ..               ...       ... ..    ...               ...   ...    ...
# 67                 1  KG LOOSE         B                30    35     32
# 68
# 69                 1  KG LOOSE                           6    12     10
# 70
# 71                 1  KG LOOSE         A                25    35     30
#
# [72 rows x 11 columns]

# %%
def getdf(list):
    df = pd.DataFrame(columns=['S', 'NAME', 'ARRIVAL_IN_TONS', 'VARIETY', 'WEIGHT_IN_KG', 'KG', 'PACKING_SIZE', 'TYPE_OF_GRADE', 'MIN_PRICE', 'MAX_PRICE', 'MODAL_PRICE', 'DATE'])
    for item in list:
        print(item)
        tables = camelot.read_pdf(item, pages="1-6")
        for i in range(6):
            if item != '2017/23062017.pdf' and item != '2017/24062017.pdf' and item != '2017/27062017.pdf':
                df1 = tables[i].df[10:] if i==0 else tables[i].df[2:]
                df1['DATE'] = item[5:13]
                df1.columns = ['S', 'NAME', 'ARRIVAL_IN_TONS', 'VARIETY', 'WEIGHT_IN_KG', 'KG', 'PACKING_SIZE', 'TYPE_OF_GRADE', 'MIN_PRICE', 'MAX_PRICE', 'MODAL_PRICE', 'DATE']
                df = pd.concat([df,df1], axis=0)
            else: 
                df1 = tables[i].df[10:] if i==0 else tables[i].df[2:]
                df1['DATE'] = item[5:13]
                df1.columns = ['S', 'NAME', 'ARRIVAL_IN_TONS', 'VARIETY', 'WEIGHT_IN_KG', 'KG', 'PACKING_SIZE', 'TYPE_OF_GRADE', 'MIN_PRICE', 'MAX_PRICE', 'MODAL_PRICE', 'ONE', 'TWO','DATE']
                df1.drop(['ONE', 'TWO'], axis=1)
                df = pd.concat([df,df1], axis=0)
    return df

# %%
df = getdf(list_2017)
# Out:
# 2017/01062017.pdf
# ---------------------------------------------------------------------------
# GhostscriptError                          Traceback (most recent call last)
# <ipython-input-97-da1093bb7e5f> in <module>
# ----> 1 df = getdf(list_2017)
#
# <ipython-input-96-20eefd520e3d> in getdf(list)
#       3     for item in list:
#       4         print(item)
# ----> 5         tables = camelot.read_pdf(item, pages="1-6")
#       6         for i in range(6):
#       7             if item != '2017/23062017.pdf' and item != '2017/24062017.pdf' and item != '2017/27062017.pdf':
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     115             suppress_stdout=suppress_stdout,
#     116             layout_kwargs=layout_kwargs,
# --> 117             **kwargs
#     118         )
#     119         return tables
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/handlers.py in parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     170             for p in pages:
#     171                 t = parser.extract_tables(
# --> 172                     p, suppress_stdout=suppress_stdout, layout_kwargs=layout_kwargs
#     173                 )
#     174                 tables.extend(t)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/parsers/lattice.py in extract_tables(self, filename, suppress_stdout, layout_kwargs)
#     400             return []
#     401
# --> 402         self._generate_image()
#     403         self._generate_table_bbox()
#     404
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/parsers/lattice.py in _generate_image(self)
#     217         gs_call = gs_call.encode().split()
#     218         null = open(os.devnull, "wb")
# --> 219         with Ghostscript(*gs_call, stdout=null) as gs:
#     220             pass
#     221         null.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/ext/ghostscript/__init__.py in Ghostscript(*args, **kwargs)
#      93         stdin=kwargs.get("stdin", None),
#      94         stdout=kwargs.get("stdout", None),
# ---> 95         stderr=kwargs.get("stderr", None),
#      96     )
#      97
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/ext/ghostscript/__init__.py in __init__(self, instance, args, stdin, stdout, stderr)
#      37         if stdin or stdout or stderr:
#      38             self.set_stdio(stdin, stdout, stderr)
# ---> 39         rc = gs.init_with_args(instance, args)
#      40         self._initialized = True
#      41         if rc == gs.e_Quit:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/ext/ghostscript/_gsprint.py in init_with_args(instance, argv)
#     172     rc = libgs.gsapi_init_with_args(instance, len(argv), c_argv)
#     173     if rc not in (0, e_Quit, e_Info):
# --> 174         raise GhostscriptError(rc)
#     175     return rc
#     176
#
# GhostscriptError: -100

# %%
df
# Out:
#       S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 10  NO.      COMM. & STATE         IN TONS                   IN KG.
# 11    1              APPLE           274.4
# 12       HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 13                                                               10  KG.
# 14                                                               25  KG.
# ..  ...                ...             ...         ...          ...  ...
# 60   53             RADISH             8.9
# 61              LOC/HAR/UP                                       40  KG.
# 62                                                               40  KG.
# 63                                                               40  KG.
# 64   54            SPINACH            32.6
#
#     PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 10  PACKING SIZE                    MINI      MAXI       MODAL  01062019
# 11                                                              01062019
# 12         C.BOX             A       800       900         850  01062019
# 13         C.BOX             B       700       780         740  01062019
# 14         C.BOX             A      2000      2200        2100  01062019
# ..           ...           ...       ...       ...         ...       ...
# 60                                                              29062019
# 61           BUN             A       400       450         420  29062019
# 62           BUN             B       340       380         360  29062019
# 63           BUN             C       200       280         240  29062019
# 64                                                              29062019
#
# [9225 rows x 12 columns]

# %%
df = df[1:]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#        S            NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG         KG  \
# 0      1           APPLE            38.8
# 1         HP/KINNAUR(CS)                  ROYAL DEL.           10  KG. C.BOX
# 2                                                              10  KG. C.BOX
# 3                                                              10  KG. C.BOX
# 4            HPS/UTK(CS)                  ROYAL DEL.           10  KG. C.BOX
# ...   ..             ...             ...         ...          ...        ...
# 9954  61        CAPSICUM            68.3
# 9955                 HAR                                        1   KG LOOSE
# 9956                                                            1   KG LOOSE
# 9957                 MAH                                        1   KG LOOSE
# 9958                  HP                                        1   KG LOOSE
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 0                                                                01062018
# 1                             A       975      1200        1050  01062018
# 2                             B       760       950         840  01062018
# 3                             C       500       750         600  01062018
# 4                             A       725      1050         770  01062018
# ...           ...           ...       ...       ...         ...       ...
# 9954                                                             30062018
# 9955                          A        50        60          55  30062018
# 9956                          B        30        35          32  30062018
# 9957                                   50        60          56  30062018
# 9958                                   55        70          60  30062018
#
# [9959 rows x 12 columns]

# %%
df.to_excel("june2019.xlsx")

# %%
dff = df.index[df['NAME'] == 'APPLE']

# %%
dff2 = df.index[df['S']=='1']

# %%
dff3 = df.index[df['WEIGHT_IN_KG'] == 'VEGETABLES']

# %%
last = df.tail(1).index
last
# Out:
# RangeIndex(start=9223, stop=9224, step=1)

# %%
dff2 = dff2.append(last)

# %%
dff2
# Out:
# Int64Index([   0,  191,  369,  565,  738,  937, 1107, 1303, 1476, 1675, 1845,
#             2044, 2214, 2410, 2583, 2786, 2952, 3159, 3321, 3531, 3690, 3900,
#             4059, 4269, 4428, 4626, 4797, 4999, 5166, 5365, 5535, 5733, 5904,
#             6102, 6273, 6472, 6642, 6833, 7011, 7205, 7380, 7563, 7749, 7928,
#             8118, 8297, 8487, 8672, 8856, 9044, 9223],
#            dtype='int64')

# %%
dffruits = df[dff2[1]:dff2[2]]
dfveggies = df[dff2[-2]:dff2[-1]]
dfveggies
# Out:
#        S        NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG   KG PACKING_SIZE  \
# 9044   1      POTATO          1128.8
# 9045          UP(CS)                                   50   KG          BAG
# 9046                                                   50   KG          BAG
# 9047        PUN/ HAR                                   50   KG          BAG
# 9048                                                   50   KG          BAG
# ...   ..         ...             ...     ...          ...  ...          ...
# 9218                                                    1   KG        LOOSE
# 9219  53      RADISH             8.9
# 9220      LOC/HAR/UP                                   40  KG.          BUN
# 9221                                                   40  KG.          BUN
# 9222                                                   40  KG.          BUN
#
#      TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 9044                                                29062019
# 9045             A       380       450         400  29062019
# 9046             B       300       360         325  29062019
# 9047             A       240       350         300  29062019
# 9048             B       150       225         180  29062019
# ...            ...       ...       ...         ...       ...
# 9218             B         3         5           4  29062019
# 9219                                                29062019
# 9220             A       400       450         420  29062019
# 9221             B       340       380         360  29062019
# 9222             C       200       280         240  29062019
#
# [179 rows x 12 columns]

# %%
df_fruits = pd.DataFrame(columns=['S', 'NAME', 'ARRIVAL_IN_TONS', 'VARIETY', 'WEIGHT_IN_KG', 'KG', 'PACKING_SIZE', 'TYPE_OF_GRADE', 'MIN_PRICE', 'MAX_PRICE', 'MODAL_PRICE'])
df_vegetables = pd.DataFrame(columns=['S', 'NAME', 'ARRIVAL_IN_TONS', 'VARIETY', 'WEIGHT_IN_KG', 'KG', 'PACKING_SIZE', 'TYPE_OF_GRADE', 'MIN_PRICE', 'MAX_PRICE', 'MODAL_PRICE'])

# %%
for j in range(0, len(dff2)-1, 2):
    df_fruits1 = df[dff2[j]:dff2[j+1]]
    print(df_fruits1)
    df_fruits = pd.concat([df_fruits, df_fruits1], axis=0)
# Out:
#       S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 0     1              APPLE           274.4
# 1        HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 2                                                                10  KG.
# 3                                                                25  KG.
# 4                                                                25  KG.
# ..   ..                ...             ...         ...          ...  ...
# 186
# 187  28        WATER MELON           751.8
# 188                 UP/RAJ                                        1   KG
# 189                                                               1   KG
# 190                                                      VEGETABLES
#
#     PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 0                                                               01062019
# 1          C.BOX             A       800       900         850  01062019
# 2          C.BOX             B       700       780         740  01062019
# 3          C.BOX             A      2000      2200        2100  01062019
# 4          C.BOX             B      1400      1900        1600  01062019
# ..           ...           ...       ...       ...         ...       ...
# 186                                                             01062019
# 187                                                             01062019
# 188        LOOSE             A         5         7           6  01062019
# 189        LOOSE             B         2         4           3  01062019
# 190                                                             01062019
#
# [191 rows x 12 columns]
#       S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 369   1              APPLE           137.2
# 370      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 371                                                              10  KG.
# 372                                                              25  KG.
# 373                                                              25  KG.
# ..   ..                ...             ...         ...          ...  ...
# 560
# 561  28        WATER MELON           132.5
# 562                 UP/RAJ                                        1   KG
# 563                                                               1   KG
# 564                                                      VEGETABLES
#
#     PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 369                                                             03062019
# 370        C.BOX             A       800       900         850  03062019
# 371        C.BOX             B       700       780         740  03062019
# 372        C.BOX             A      2000      2200        2100  03062019
# 373        C.BOX             B      1400      1900        1600  03062019
# ..           ...           ...       ...       ...         ...       ...
# 560                                                             03062019
# 561                                                             03062019
# 562        LOOSE             A         5         6           5  03062019
# 563        LOOSE             B         2         4           3  03062019
# 564                                                             03062019
#
# [196 rows x 12 columns]
#       S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 738   1              APPLE           315.3
# 739      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 740                                                              10  KG.
# 741                                                              25  KG.
# 742                                                              25  KG.
# ..   ..                ...             ...         ...          ...  ...
# 932
# 933  28        WATER MELON          1281.4
# 934                 UP/RAJ                                        1   KG
# 935                                                               1   KG
# 936                                                      VEGETABLES
#
#     PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 738                                                             04062019
# 739        C.BOX             A       800       900         850  04062019
# 740        C.BOX             B       700       780         740  04062019
# 741        C.BOX             A      2000      2200        2100  04062019
# 742        C.BOX             B      1400      1900        1600  04062019
# ..           ...           ...       ...       ...         ...       ...
# 932                                                             04062019
# 933                                                             04062019
# 934        LOOSE             A         5         6           5  04062019
# 935        LOOSE             B         2         4           3  04062019
# 936                                                             04062019
#
# [199 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 1107   1              APPLE           180.9
# 1108      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 1109                                                              10  KG.
# 1110                                                              25  KG.
# 1111                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 1298
# 1299  28        WATER MELON           726.2
# 1300                 UP/RAJ                                        1   KG
# 1301                                                               1   KG
# 1302                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 1107                                                             05062019
# 1108        C.BOX             A       800       850         820  05062019
# 1109        C.BOX             B       700       780         740  05062019
# 1110        C.BOX             A      2000      2100        2050  05062019
# 1111        C.BOX             B      1400      1900        1600  05062019
# ...           ...           ...       ...       ...         ...       ...
# 1298                                                             05062019
# 1299                                                             05062019
# 1300        LOOSE             A         5         6           5  05062019
# 1301        LOOSE             B         2         4           3  05062019
# 1302                                                             05062019
#
# [196 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 1476   1              APPLE            98.7
# 1477      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 1478                                                              10  KG.
# 1479                                                              25  KG.
# 1480                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 1670
# 1671  28        WATER MELON           228.9
# 1672                 UP/RAJ                                        1   KG
# 1673                                                               1   KG
# 1674                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 1476                                                             06062019
# 1477        C.BOX             A       800       850         820  06062019
# 1478        C.BOX             B       700       780         740  06062019
# 1479        C.BOX             A      2000      2100        2050  06062019
# 1480        C.BOX             B      1400      1900        1600  06062019
# ...           ...           ...       ...       ...         ...       ...
# 1670                                                             06062019
# 1671                                                             06062019
# 1672        LOOSE             A         5         6           5  06062019
# 1673        LOOSE             B         2         4           3  06062019
# 1674                                                             06062019
#
# [199 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 1845   1              APPLE           142.1
# 1846      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 1847                                                              10  KG.
# 1848                                                              25  KG.
# 1849                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 2039
# 2040  28        WATER MELON           509.0
# 2041                 UP/RAJ                                        1   KG
# 2042                                                               1   KG
# 2043                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 1845                                                             07062019
# 1846        C.BOX             A       800       850         820  07062019
# 1847        C.BOX             B       700       780         740  07062019
# 1848        C.BOX             A      2000      2100        2050  07062019
# 1849        C.BOX             B      1400      1900        1600  07062019
# ...           ...           ...       ...       ...         ...       ...
# 2039                                                             07062019
# 2040                                                             07062019
# 2041        LOOSE             A         5         6           5  07062019
# 2042        LOOSE             B         2         4           3  07062019
# 2043                                                             07062019
#
# [199 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 2214   1              APPLE           129.6
# 2215      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 2216                                                              10  KG.
# 2217                                                              25  KG.
# 2218                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 2405
# 2406  28        WATER MELON          1314.2
# 2407                 UP/RAJ                                        1   KG
# 2408                                                               1   KG
# 2409                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 2214                                                             08062019
# 2215        C.BOX             A       800       850         820  08062019
# 2216        C.BOX             B       700       780         740  08062019
# 2217        C.BOX             A      2000      2100        2050  08062019
# 2218        C.BOX             B      1400      1900        1600  08062019
# ...           ...           ...       ...       ...         ...       ...
# 2405                                                             08062019
# 2406                                                             08062019
# 2407        LOOSE             A         6         8           7  08062019
# 2408        LOOSE             B         2         5           4  08062019
# 2409                                                             08062019
#
# [196 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 2583   1              APPLE           243.3
# 2584      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 2585                                                              10  KG.
# 2586                                                              25  KG.
# 2587                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 2781
# 2782  28        WATER MELON           242.3
# 2783                 UP/RAJ                                        1   KG
# 2784                                                               1   KG
# 2785                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 2583                                                             10062019
# 2584        C.BOX             A       800       850         820  10062019
# 2585        C.BOX             B       700       780         740  10062019
# 2586        C.BOX             A      2000      2100        2050  10062019
# 2587        C.BOX             B      1400      1900        1600  10062019
# ...           ...           ...       ...       ...         ...       ...
# 2781                                                             10062019
# 2782                                                             10062019
# 2783        LOOSE             A         5         7           6  10062019
# 2784        LOOSE             B         2         4           3  10062019
# 2785                                                             10062019
#
# [203 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 2952   1              APPLE           259.6
# 2953      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 2954                                                              10  KG.
# 2955                                                              25  KG.
# 2956                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 3154
# 3155  28        WATER MELON          1456.6
# 3156                 UP/RAJ                                        1   KG
# 3157                                                               1   KG
# 3158                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 2952                                                             11062019
# 2953        C.BOX             A       800       850         820  11062019
# 2954        C.BOX             B       700       780         740  11062019
# 2955        C.BOX             A      2000      2100        2050  11062019
# 2956        C.BOX             B      1400      1900        1600  11062019
# ...           ...           ...       ...       ...         ...       ...
# 3154                                                             11062019
# 3155                                                             11062019
# 3156        LOOSE             A         5         6           5  11062019
# 3157        LOOSE             B         2         4           3  11062019
# 3158                                                             11062019
#
# [207 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 3321   1              APPLE           239.1
# 3322      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 3323                                                              10  KG.
# 3324                                                              25  KG.
# 3325                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 3526
# 3527  28        WATER MELON           881.9
# 3528                 UP/RAJ                                        1   KG
# 3529                                                               1   KG
# 3530                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 3321                                                             12062019
# 3322        C.BOX             A       800       850         820  12062019
# 3323        C.BOX             B       700       780         740  12062019
# 3324        C.BOX             A      2000      2100        2050  12062019
# 3325        C.BOX             B      1400      1900        1600  12062019
# ...           ...           ...       ...       ...         ...       ...
# 3526                                                             12062019
# 3527                                                             12062019
# 3528        LOOSE             A         5         7           6  12062019
# 3529        LOOSE             B         2         4           3  12062019
# 3530                                                             12062019
#
# [210 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 3690   1              APPLE           172.6
# 3691      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 3692                                                              10  KG.
# 3693                                                              25  KG.
# 3694                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 3895
# 3896  28        WATER MELON           786.8
# 3897                 UP/RAJ                                        1   KG
# 3898                                                               1   KG
# 3899                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 3690                                                             13062019
# 3691        C.BOX             A       800       850         820  13062019
# 3692        C.BOX             B       700       780         740  13062019
# 3693        C.BOX             A      2000      2100        2050  13062019
# 3694        C.BOX             B      1400      1900        1600  13062019
# ...           ...           ...       ...       ...         ...       ...
# 3895                                                             13062019
# 3896                                                             13062019
# 3897        LOOSE             A         5         7           6  13062019
# 3898        LOOSE             B         2         4           3  13062019
# 3899                                                             13062019
#
# [210 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 4059   1              APPLE           234.1
# 4060      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 4061                                                              10  KG.
# 4062                                                              25  KG.
# 4063                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 4264
# 4265  28        WATER MELON           535.8
# 4266                 UP/RAJ                                        1   KG
# 4267                                                               1   KG
# 4268                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 4059                                                             14062019
# 4060        C.BOX             A       750       800         760  14062019
# 4061        C.BOX             B       600       680         650  14062019
# 4062        C.BOX             A      1900      2100        2000  14062019
# 4063        C.BOX             B      1400      1800        1500  14062019
# ...           ...           ...       ...       ...         ...       ...
# 4264                                                             14062019
# 4265                                                             14062019
# 4266        LOOSE             A         5         7           6  14062019
# 4267        LOOSE             B         2         4           3  14062019
# 4268                                                             14062019
#
# [210 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 4428   1              APPLE            75.5
# 4429      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 4430                                                              10  KG.
# 4431                                                              25  KG.
# 4432                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 4621
# 4622  28        WATER MELON           741.6
# 4623                 UP/RAJ                                        1   KG
# 4624                                                               1   KG
# 4625                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 4428                                                             15062019
# 4429        C.BOX             A       750       800         760  15062019
# 4430        C.BOX             B       600       680         650  15062019
# 4431        C.BOX             A      1900      2100        2000  15062019
# 4432        C.BOX             B      1400      1800        1500  15062019
# ...           ...           ...       ...       ...         ...       ...
# 4621                                                             15062019
# 4622                                                             15062019
# 4623        LOOSE             A         5         7           6  15062019
# 4624        LOOSE             B         2         4           3  15062019
# 4625                                                             15062019
#
# [198 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 4797   1              APPLE            11.1
# 4798      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 4799                                                              10  KG.
# 4800                                                              25  KG.
# 4801                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 4994
# 4995  28        WATER MELON            50.2
# 4996                 UP/RAJ                                        1   KG
# 4997                                                               1   KG
# 4998                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 4797                                                             17062019
# 4798        C.BOX             A       750       800         760  17062019
# 4799        C.BOX             B       600       680         650  17062019
# 4800        C.BOX             A      1900      2100        2000  17062019
# 4801        C.BOX             B      1400      1800        1500  17062019
# ...           ...           ...       ...       ...         ...       ...
# 4994                                                             17062019
# 4995                                                             17062019
# 4996        LOOSE             A         5         7           6  17062019
# 4997        LOOSE             B         2         4           3  17062019
# 4998                                                             17062019
#
# [202 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 5166   1              APPLE           158.8
# 5167      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 5168                                                              10  KG.
# 5169                                                              25  KG.
# 5170                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 5360
# 5361  28        WATER MELON           773.8
# 5362                 UP/RAJ                                        1   KG
# 5363                                                               1   KG
# 5364                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 5166                                                             18062019
# 5167        C.BOX             A       750       800         760  18062019
# 5168        C.BOX             B       600       680         650  18062019
# 5169        C.BOX             A      1900      2100        2000  18062019
# 5170        C.BOX             B      1400      1800        1500  18062019
# ...           ...           ...       ...       ...         ...       ...
# 5360                                                             18062019
# 5361                                                             18062019
# 5362        LOOSE             A         5         7           6  18062019
# 5363        LOOSE             B         2         4           3  18062019
# 5364                                                             18062019
#
# [199 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 5535   1              APPLE            94.6
# 5536      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 5537                                                              10  KG.
# 5538                                                              25  KG.
# 5539                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 5728
# 5729  28        WATER MELON           497.7
# 5730                 UP/RAJ                                        1   KG
# 5731                                                               1   KG
# 5732                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 5535                                                             19062019
# 5536        C.BOX             A       750       800         760  19062019
# 5537        C.BOX             B       600       680         650  19062019
# 5538        C.BOX             A      1900      2100        2000  19062019
# 5539        C.BOX             B      1400      1800        1500  19062019
# ...           ...           ...       ...       ...         ...       ...
# 5728                                                             19062019
# 5729                                                             19062019
# 5730        LOOSE             A         5         7           6  19062019
# 5731        LOOSE             B         2         4           3  19062019
# 5732                                                             19062019
#
# [198 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 5904   1              APPLE           153.3
# 5905      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 5906                                                              10  KG.
# 5907                                                              25  KG.
# 5908                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 6097
# 6098  28        WATER MELON           432.5
# 6099                 UP/RAJ                                        1   KG
# 6100                                                               1   KG
# 6101                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 5904                                                             20062019
# 5905        C.BOX             A       750       800         760  20062019
# 5906        C.BOX             B       600       680         650  20062019
# 5907        C.BOX             A      1900      2100        2000  20062019
# 5908        C.BOX             B      1400      1800        1500  20062019
# ...           ...           ...       ...       ...         ...       ...
# 6097                                                             20062019
# 6098                                                             20062019
# 6099        LOOSE             A         5         7           6  20062019
# 6100        LOOSE             B         2         4           3  20062019
# 6101                                                             20062019
#
# [198 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 6273   1              APPLE            36.4
# 6274      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 6275                                                              10  KG.
# 6276                                                              25  KG.
# 6277                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 6467
# 6468  28        WATER MELON           460.4
# 6469                 UP/RAJ                                        1   KG
# 6470                                                               1   KG
# 6471                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 6273                                                             21062019
# 6274        C.BOX             A       750       800         760  21062019
# 6275        C.BOX             B       600       680         650  21062019
# 6276        C.BOX             A      1900      2100        2000  21062019
# 6277        C.BOX             B      1400      1800        1500  21062019
# ...           ...           ...       ...       ...         ...       ...
# 6467                                                             21062019
# 6468                                                             21062019
# 6469        LOOSE             A         5         7           6  21062019
# 6470        LOOSE             B         2         4           3  21062019
# 6471                                                             21062019
#
# [199 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 6642   1              APPLE            47.1
# 6643      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 6644                                                              10  KG.
# 6645                                                              25  KG.
# 6646                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 6828
# 6829  27        WATER MELON           298.2
# 6830                 UP/RAJ                                        1   KG
# 6831                                                               1   KG
# 6832                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 6642                                                             22062019
# 6643        C.BOX             A       750       800         760  22062019
# 6644        C.BOX             B       600       680         650  22062019
# 6645        C.BOX             A      1900      2100        2000  22062019
# 6646        C.BOX             B      1400      1800        1500  22062019
# ...           ...           ...       ...       ...         ...       ...
# 6828                                                             22062019
# 6829                                                             22062019
# 6830        LOOSE             A         5         7           6  22062019
# 6831        LOOSE             B         2         4           3  22062019
# 6832                                                             22062019
#
# [191 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 7011   1              APPLE
# 7012      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 7013                                                              10  KG.
# 7014                                                              25  KG.
# 7015                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 7200
# 7201  27        WATER MELON            30.0
# 7202                 UP/RAJ                                        1   KG
# 7203                                                               1   KG
# 7204                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 7011                                                             24062019
# 7012        C.BOX             A       750       800         760  24062019
# 7013        C.BOX             B       600       680         650  24062019
# 7014        C.BOX             A      1900      2100        2000  24062019
# 7015        C.BOX             B      1400      1800        1500  24062019
# ...           ...           ...       ...       ...         ...       ...
# 7200                                                             24062019
# 7201                                                             24062019
# 7202        LOOSE             A         5         7           6  24062019
# 7203        LOOSE             B         2         4           3  24062019
# 7204                                                             24062019
#
# [194 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 7380   1              APPLE            64.2
# 7381      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 7382                                                              10  KG.
# 7383                                                              25  KG.
# 7384                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 7558                  UP/HR                                      100  KG.
# 7559  27        WATER MELON           520.6
# 7560                 UP/RAJ                                    KG\n1
# 7561                                                           KG\n1
# 7562                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 7380                                                             25062019
# 7381        C.BOX             A       750       950         800  25062019
# 7382        C.BOX             B       600       680         650  25062019
# 7383        C.BOX             A      1700      2000        1800  25062019
# 7384        C.BOX             B      1400      1600        1500  25062019
# ...           ...           ...       ...       ...         ...       ...
# 7558        LOOSE                     800      1000         940  25062019
# 7559                                                             25062019
# 7560        LOOSE             A         5         7           6  25062019
# 7561        LOOSE             B         3         4           4  25062019
# 7562                                                             25062019
#
# [183 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 7749   1              APPLE            83.5
# 7750      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 7751                                                              10  KG.
# 7752                                                              25  KG.
# 7753                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 7923                  UP/HR                                      100  KG.
# 7924  27        WATER MELON           450.3
# 7925                 UP/RAJ                                        1   KG
# 7926                                                               1   KG
# 7927                                                      VEGETABLES
#
#         PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 7749                                                                26062019
# 7750           C.BOX             A       750       950         800  26062019
# 7751           C.BOX             B       600       680         650  26062019
# 7752           C.BOX             A      1700      2000        1800  26062019
# 7753           C.BOX             B      1400      1600        1500  26062019
# ...              ...           ...       ...       ...         ...       ...
# 7923           LOOSE                     800      1000         940  26062019
# 7924                                                                26062019
# 7925  LOOSE\nA\n5\n7                                             6  26062019
# 7926  LOOSE\nB\n3\n4                                             4  26062019
# 7927                                                                26062019
#
# [179 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 8118   1              APPLE            31.4
# 8119      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 8120                                                              10  KG.
# 8121                                                              25  KG.
# 8122                                                              25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 8292                  UP/HR                                      100  KG.
# 8293  27        WATER MELON           382.4
# 8294                 UP/RAJ                                        1   KG
# 8295                                                               1   KG
# 8296                                                      VEGETABLES
#
#         PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 8118                                                                27062019
# 8119           C.BOX             A       750       950         800  27062019
# 8120           C.BOX             B       600       680         650  27062019
# 8121           C.BOX             A      1700      2000        1800  27062019
# 8122           C.BOX             B      1400      1600        1500  27062019
# ...              ...           ...       ...       ...         ...       ...
# 8292           LOOSE                     800       900         850  27062019
# 8293                                                                27062019
# 8294  LOOSE\nA\n5\n7                                             6  27062019
# 8295  LOOSE\nB\n3\n4                                             4  27062019
# 8296                                                                27062019
#
# [179 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 8487   1              APPLE            93.6
# 8488      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 8489                                                              10  KG.
# 8490         UTK/SHIMLA(CS)                                       10  KG.
# 8491                                                              10  KG.
# ...   ..                ...             ...         ...          ...  ...
# 8667                  UP/HR                                      100  KG.
# 8668  27        WATER MELON           442.0
# 8669                 UP/RAJ                                        1   KG
# 8670                                                               1   KG
# 8671                                                      VEGETABLES
#
#          PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 8487                                                                 28062019
# 8488            C.BOX             A       750       950         800  28062019
# 8489            C.BOX             B       600       680         650  28062019
# 8490            C.BOX             A       650       800         700  28062019
# 8491            C.BOX             B       600       640         620  28062019
# ...               ...           ...       ...       ...         ...       ...
# 8667  LOOSE\n800\n900                                           850  28062019
# 8668                                                                 28062019
# 8669            LOOSE             A         6         7           6  28062019
# 8670            LOOSE             B         4         5           4  28062019
# 8671                                                                 28062019
#
# [185 rows x 12 columns]
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 8856   1              APPLE            52.2
# 8857      HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 8858                                                              10  KG.
# 8859         UTK/SHIMLA(CS)                                       10  KG.
# 8860                                                              10  KG.
# ...   ..                ...             ...         ...          ...  ...
# 9039  27        WATER MELON           366.9
# 9040                 UP/RAJ                                        1   KG
# 9041                                                               1   KG
# 9042
# 9043                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 8856                                                             29062019
# 8857        C.BOX             A       750       900         800  29062019
# 8858        C.BOX             B       600       680         650  29062019
# 8859        C.BOX             A       700       800         725  29062019
# 8860        C.BOX             B       600       680         620  29062019
# ...           ...           ...       ...       ...         ...       ...
# 9039                                                             29062019
# 9040        LOOSE             A         6         7           6  29062019
# 9041        LOOSE             B         4         5           5  29062019
# 9042                                                             29062019
# 9043                                                             29062019
#
# [188 rows x 12 columns]

# %%
for j in range(1, len(dff2)-1, 2):
    df_veg1 = df[dff2[j]:dff2[j+1]]
    print(df_veg1)
    df_vegetables = pd.concat([df_vegetables, df_veg1], axis=0)
# Out:
#        S                        NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 191    1                      POTATO          1059.5
# 192                           UP(CS)                                   50  KG
# 193                                                                    50  KG
# 194                      UP/SAMSABAD                                   50  KG
# 195                                                                    50  KG
# ..   ...                         ...             ...     ...          ...  ..
# 364   54                     PUMPKIN            54.0
# 365       UP/W.B/GUJ/RAJ/HR/KOLKATTA                                    1  KG
# 366                                                                     1  KG
# 367   55                RADISH\n19.5
# 368  NO.               COMM. & STATE         IN TONS               IN KG.
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 191                                                              01062019
# 192           BAG             A       400       460         425  01062019
# 193           BAG             B       200       350         300  01062019
# 194           BAG             A       350       450         375  01062019
# 195           BAG             B       290       340         300  01062019
# ..            ...           ...       ...       ...         ...       ...
# 364                                                              01062019
# 365         LOOSE             A         6         8           7  01062019
# 366         LOOSE             B         3         5           4  01062019
# 367                                                              01062019
# 368  PACKING SIZE                    MINI      MAXI       MODAL  03062019
#
# [178 rows x 12 columns]
#        S                        NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 565    1                      POTATO           134.2
# 566                           UP(CS)                                   50  KG
# 567                                                                    50  KG
# 568                      UP/SAMSABAD                                   50  KG
# 569                                                                    50  KG
# ..   ...                         ...             ...     ...          ...  ..
# 733   53                       PHUEE
# 734                               UP                                    1  KG
# 735   54                     PUMPKIN            24.0
# 736       UP/W.B/GUJ/RAJ/HR/KOLKATTA                                    1  KG
# 737  NO.               COMM. & STATE         IN TONS               IN KG.
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 565                                                              03062019
# 566           BAG             A       300       400         350  03062019
# 567           BAG             B       200       280         225  03062019
# 568           BAG             A       350       400         360  03062019
# 569           BAG             B       290       340         300  03062019
# ..            ...           ...       ...       ...         ...       ...
# 733                                                              03062019
# 734         LOOSE                      12        16          14  03062019
# 735                                                              03062019
# 736         LOOSE             A         6         8           7  03062019
# 737  PACKING SIZE                    MINI      MAXI       MODAL  04062019
#
# [173 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 937     1         POTATO          1078.6
# 938               UP(CS)                                   50  KG
# 939                                                        50  KG
# 940          UP/SAMSABAD                                   50  KG
# 941                                                        50  KG
# ...   ...            ...             ...     ...          ...  ..
# 1102   52         PERMAL            87.5
# 1103                  UP                                    1  KG
# 1104                                                        1  KG
# 1105   53          PHUEE
# 1106  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 937                                                               04062019
# 938            BAG             A       300       400         350  04062019
# 939            BAG             B       200       280         225  04062019
# 940            BAG             A       350       400         360  04062019
# 941            BAG             B       290       340         300  04062019
# ...            ...           ...       ...       ...         ...       ...
# 1102                                                              04062019
# 1103         LOOSE             A        10        14          12  04062019
# 1104         LOOSE             B         6         8           7  04062019
# 1105                                                              04062019
# 1106  PACKING SIZE                    MINI      MAXI       MODAL  05062019
#
# [170 rows x 12 columns]
#         S                        NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  \
# 1303    1                      POTATO           954.5
# 1304                           UP(CS)                                   50
# 1305                                                                    50
# 1306                      UP/SAMSABAD                                   50
# 1307                                                                    50
# ...   ...                         ...             ...     ...          ...
# 1471   53                       PHUEE
# 1472                               UP                                    1
# 1473   54                     PUMPKIN            88.1
# 1474       UP/W.B/GUJ/RAJ/HR/KOLKATTA                                    1
# 1475  NO.               COMM. & STATE         IN TONS               IN KG.
#
#       KG  PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 1303                                                                  05062019
# 1304  KG           BAG             A       300       400         350  05062019
# 1305  KG           BAG             B       200       280         225  05062019
# 1306  KG           BAG             A       350       400         360  05062019
# 1307  KG           BAG             B       290       340         300  05062019
# ...   ..           ...           ...       ...       ...         ...       ...
# 1471                                                                  05062019
# 1472  KG         LOOSE                      12        16          14  05062019
# 1473                                                                  05062019
# 1474  KG         LOOSE             A         6         8           7  05062019
# 1475      PACKING SIZE                    MINI      MAXI       MODAL  06062019
#
# [173 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 1675    1         POTATO           578.2
# 1676              UP(CS)                                   50  KG
# 1677                                                       50  KG
# 1678         UP/SAMSABAD                                   50  KG
# 1679                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 1840   52         PERMAL            99.4
# 1841                  UP                                    1  KG
# 1842                                                        1  KG
# 1843   53          PHUEE
# 1844  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 1675                                                              06062019
# 1676           BAG             A       300       400         350  06062019
# 1677           BAG             B       200       280         225  06062019
# 1678           BAG             A       350       400         360  06062019
# 1679           BAG             B       290       340         300  06062019
# ...            ...           ...       ...       ...         ...       ...
# 1840                                                              06062019
# 1841         LOOSE             A        10        14          12  06062019
# 1842         LOOSE             B         6         8           7  06062019
# 1843                                                              06062019
# 1844  PACKING SIZE                    MINI      MAXI       MODAL  07062019
#
# [170 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 2044    1         POTATO           882.0
# 2045              UP(CS)                                   50  KG
# 2046                                                       50  KG
# 2047         UP/SAMSABAD                                   50  KG
# 2048                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 2209                                                        1  KG
# 2210   52         PERMAL            87.5
# 2211                  UP                                    1  KG
# 2212                                                        1  KG
# 2213  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 2044                                                              07062019
# 2045           BAG             A       300       400         350  07062019
# 2046           BAG             B       200       280         225  07062019
# 2047           BAG             A       350       400         360  07062019
# 2048           BAG             B       290       340         300  07062019
# ...            ...           ...       ...       ...         ...       ...
# 2209         LOOSE             B        30        38          35  07062019
# 2210                                                              07062019
# 2211         LOOSE             A        10        14          12  07062019
# 2212         LOOSE             B         6         8           7  07062019
# 2213  PACKING SIZE                    MINI      MAXI       MODAL  08062019
#
# [170 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 2410    1         POTATO          1068.7
# 2411              UP(CS)                                   50  KG
# 2412                                                       50  KG
# 2413         UP/SAMSABAD                                   50  KG
# 2414                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 2578   52         PERMAL            94.4
# 2579                  UP                                    1  KG
# 2580                                                        1  KG
# 2581   53          PHUEE
# 2582  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 2410                                                              08062019
# 2411           BAG             A       300       400         350  08062019
# 2412           BAG             B       200       280         225  08062019
# 2413           BAG             A       350       400         360  08062019
# 2414           BAG             B       290       340         300  08062019
# ...            ...           ...       ...       ...         ...       ...
# 2578                                                              08062019
# 2579         LOOSE             A        10        14          12  08062019
# 2580         LOOSE             B         6         8           7  08062019
# 2581                                                              08062019
# 2582  PACKING SIZE                    MINI      MAXI       MODAL  10062019
#
# [173 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG  KG  \
# 2786    1         POTATO           119.6
# 2787              UP(CS)                                       50  KG
# 2788                                                           50  KG
# 2789         UP/SAMSABAD                                       50  KG
# 2790                                                           50  KG
# ...   ...            ...             ...         ...          ...  ..
# 2947          LOC/HAR/UP                  WHITE/BLUE            1  KG
# 2948                                                            1  KG
# 2949   51           PEAS            26.4
# 2950                 J&K                                        1  KG
# 2951  NO.  COMM. & STATE         IN TONS                   IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 2786                                                              10062019
# 2787           BAG             A       300       400         350  10062019
# 2788           BAG             B       200       280         225  10062019
# 2789           BAG             A       350       400         360  10062019
# 2790           BAG             B       290       340         300  10062019
# ...            ...           ...       ...       ...         ...       ...
# 2947         LOOSE             A        14        18          16  10062019
# 2948         LOOSE             B        10        12          11  10062019
# 2949                                                              10062019
# 2950         LOOSE             A        30        35          32  10062019
# 2951  PACKING SIZE                    MINI      MAXI       MODAL  11062019
#
# [166 rows x 12 columns]
#         S                NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 3159    1              POTATO          1413.0
# 3160                   UP(CS)                                   50  KG
# 3161                                                            50  KG
# 3162              UP/SAMSABAD                                   50  KG
# 3163                                                            50  KG
# ...   ...                 ...             ...     ...          ...  ..
# 3316                      HAR                                   40  KG
# 3317       KHAIRTAL/RAJ/ALWAR                                   40  KG
# 3318                                             GOLI           40  KG
# 3319   50             G.ONION             6.0
# 3320  NO.       COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 3159                                                              11062019
# 3160           BAG             A       300       400         350  11062019
# 3161           BAG             B       200       280         225  11062019
# 3162           BAG             A       350       400         360  11062019
# 3163           BAG             B       290       340         300  11062019
# ...            ...           ...       ...       ...         ...       ...
# 3316         KATTA                     400       500         450  11062019
# 3317         KATTA                     200       400         300  11062019
# 3318         KATTA                      80       150          90  11062019
# 3319                                                              11062019
# 3320  PACKING SIZE                    MINI      MAXI       MODAL  12062019
#
# [162 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 3531    1         POTATO           972.3
# 3532              UP(CS)                                   50  KG
# 3533                                                       50  KG
# 3534         UP/SAMSABAD                                   50  KG
# 3535                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 3685           MP-INDORE                                   40  KG
# 3686                 HAR                                   40  KG
# 3687           RAJ/ALWAR                                   40  KG
# 3688        RAJ/KHAIRTAL                                   40  KG
# 3689  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 3531                                                              12062019
# 3532           BAG             A       300       400         350  12062019
# 3533           BAG             B       200       280         225  12062019
# 3534           BAG             A       350       400         360  12062019
# 3535           BAG             B       290       340         300  12062019
# ...            ...           ...       ...       ...         ...       ...
# 3685         KATTA                     400       550         450  12062019
# 3686         KATTA                     500       600         540  12062019
# 3687         KATTA                     250       400         280  12062019
# 3688         KATTA             A       350       400         360  12062019
# 3689  PACKING SIZE                    MINI      MAXI       MODAL  13062019
#
# [159 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 3900    1         POTATO           897.4
# 3901              UP(CS)                                   50  KG
# 3902                                                       50  KG
# 3903         UP/SAMSABAD                                   50  KG
# 3904                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 4054                                                       40  KG
# 4055           MP-INDORE                                   40  KG
# 4056                 HAR                                   40  KG
# 4057           RAJ/ALWAR                                   40  KG
# 4058  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 3900                                                              13062019
# 3901           BAG             A       300       400         350  13062019
# 3902           BAG             B       200       280         225  13062019
# 3903           BAG             A       350       400         360  13062019
# 3904           BAG             B       290       340         300  13062019
# ...            ...           ...       ...       ...         ...       ...
# 4054         KATTA             B       500       580         550  13062019
# 4055         KATTA                     400       550         450  13062019
# 4056         KATTA                     500       600         540  13062019
# 4057         KATTA                     250       400         280  13062019
# 4058  PACKING SIZE                    MINI      MAXI       MODAL  14062019
#
# [159 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 4269    1         POTATO           948.5
# 4270              UP(CS)                                   50  KG
# 4271                                                       50  KG
# 4272         UP/SAMSABAD                                   50  KG
# 4273                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 4423                                                       40  KG
# 4424           MP-INDORE                                   40  KG
# 4425                 HAR                                   40  KG
# 4426           RAJ/ALWAR                                   40  KG
# 4427  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 4269                                                              14062019
# 4270           BAG             A       300       400         350  14062019
# 4271           BAG             B       200       280         225  14062019
# 4272           BAG             A       350       400         360  14062019
# 4273           BAG             B       290       340         300  14062019
# ...            ...           ...       ...       ...         ...       ...
# 4423         KATTA             B       500       580         550  14062019
# 4424         KATTA                     400       550         450  14062019
# 4425         KATTA                     500       600         540  14062019
# 4426         KATTA                     250       400         280  14062019
# 4427  PACKING SIZE                    MINI      MAXI       MODAL  15062019
#
# [159 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 4626    1         POTATO          1173.3
# 4627              UP(CS)                                   50  KG
# 4628                                                       50  KG
# 4629         UP/SAMSABAD                                   50  KG
# 4630                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 4792                  HP                                    1  KG
# 4793                                                        1  KG
# 4794
# 4795   51         PERMAL            85.2
# 4796  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 4626                                                              15062019
# 4627           BAG             A       300       400         350  15062019
# 4628           BAG             B       200       280         225  15062019
# 4629           BAG             A       350       400         360  15062019
# 4630           BAG             B       290       340         300  15062019
# ...            ...           ...       ...       ...         ...       ...
# 4792         LOOSE             A        40        60          50  15062019
# 4793         LOOSE             B        30        38          35  15062019
# 4794                                                              15062019
# 4795                                                              15062019
# 4796  PACKING SIZE                    MINI      MAXI       MODAL  17062019
#
# [171 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 4999    1         POTATO
# 5000              UP(CS)                                   50  KG
# 5001                                                       50  KG
# 5002         UP/SAMSABAD                                   50  KG
# 5003                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 5161                 J&K                                    1  KG
# 5162                                                        1  KG
# 5163                  HP                                    1  KG
# 5164                                                        1  KG
# 5165  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 4999                                                              17062019
# 5000           BAG             A       300       400         350  17062019
# 5001           BAG             B       200       280         225  17062019
# 5002           BAG             A       350       400         360  17062019
# 5003           BAG             B       290       340         300  17062019
# ...            ...           ...       ...       ...         ...       ...
# 5161         LOOSE             A        30        35          32  17062019
# 5162         LOOSE             B        15        28          22  17062019
# 5163         LOOSE             A        55        65          68  17062019
# 5164         LOOSE             B        30        45          38  17062019
# 5165  PACKING SIZE                    MINI      MAXI       MODAL  18062019
#
# [167 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 5365    1         POTATO          1620.7
# 5366              UP(CS)                                   50  KG
# 5367                                                       50  KG
# 5368         UP/SAMSABAD                                   50  KG
# 5369                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 5530   50           PEAS            60.6
# 5531                 J&K                                    1  KG
# 5532                                                        1  KG
# 5533                  HP                                    1  KG
# 5534  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 5365                                                              18062019
# 5366           BAG             A       300       400         350  18062019
# 5367           BAG             B       200       280         225  18062019
# 5368           BAG             A       400       480         420  18062019
# 5369           BAG             B       330       390         350  18062019
# ...            ...           ...       ...       ...         ...       ...
# 5530                                                              18062019
# 5531         LOOSE             A        30        35          32  18062019
# 5532         LOOSE             B        15        28          22  18062019
# 5533         LOOSE             A        55        65          68  18062019
# 5534  PACKING SIZE                    MINI      MAXI       MODAL  19062019
#
# [170 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
#
rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG  KG  \
# 7205    1         POTATO             5.0
# 7206              UP(CS)                                   50  KG
# 7207                                                       50  KG
# 7208         UP/SAMSABAD                                   50  KG
# 7209                                                       50  KG
# ...   ...            ...             ...     ...          ...  ..
# 7375                                                        1  KG
# 7376
# 7377   50         PERMAL            67.2
# 7378                  UP                                    1  KG
# 7379  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 7205                                                              24062019
# 7206           BAG             A       350       400         360  24062019
# 7207           BAG             B       230       330         280  24062019
# 7208           BAG             A       400       500         450  24062019
# 7209           BAG             B       330       390         350  24062019
# ...            ...           ...       ...       ...         ...       ...
# 7375         LOOSE             B        30        45          38  24062019
# 7376                                                              24062019
# 7377                                                              24062019
# 7378         LOOSE             A        10        14          12  24062019
# 7379  PACKING SIZE                    MINI      MAXI       MODAL  25062019
#
# [175 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG   KG  \
# 7563    1         POTATO          1498.9
# 7564              UP(CS)                                   50   KG
# 7565                                                       50   KG
# 7566         UP/SAMSABAD                                   50   KG
# 7567                                                       50   KG
# ...   ...            ...             ...     ...          ...  ...
# 7744                                                       40  KG.
# 7745   54        SPINACH            27.4
# 7746          LOC/HAR/UP                                   40  KG.
# 7747                                                       40  KG.
# 7748  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 7563                                                              25062019
# 7564           BAG             A       350       400         360  25062019
# 7565           BAG             B       230       330         280  25062019
# 7566           BAG             A       400       500         450  25062019
# 7567           BAG             B       330       390         350  25062019
# ...            ...           ...       ...       ...         ...       ...
# 7744           BUN             C       200       280         240  25062019
# 7745                                                              25062019
# 7746           BUN             A       300       400         350  25062019
# 7747           BUN             B       200       280         240  25062019
# 7748  PACKING SIZE                    MINI      MAXI       MODAL  26062019
#
# [186 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG   KG  \
# 7928    1         POTATO           877.0
# 7929              UP(CS)                                   50   KG
# 7930                                                       50   KG
# 7931         UP/SAMSABAD                                   50   KG
# 7932                                                       50   KG
# ...   ...            ...             ...     ...          ...  ...
# 8113                                                       40  KG.
# 8114
# 8115   55          SALAD             4.7
# 8116        LOC/LAHOL/HP                                    1   KG
# 8117  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 7928                                                              26062019
# 7929           BAG             A       350       400         360  26062019
# 7930           BAG             B       230       330         280  26062019
# 7931           BAG             A       400       500         450  26062019
# 7932           BAG             B       330       390         350  26062019
# ...            ...           ...       ...       ...         ...       ...
# 8113           BUN             C       120       180         140  26062019
# 8114                                                              26062019
# 8115                                                              26062019
# 8116         LOOSE                      40        50          45  26062019
# 8117  PACKING SIZE                    MINI      MAXI       MODAL  27062019
#
# [190 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG   KG  \
# 8297    1         POTATO          1073.7
# 8298              UP(CS)                                   50   KG
# 8299                                                       50   KG
# 8300         UP/SAMSABAD                                   50   KG
# 8301                                                       50   KG
# ...   ...            ...             ...     ...          ...  ...
# 8482          LOC/HAR/UP                                   40  KG.
# 8483                                                       40  KG.
# 8484                                                       40  KG.
# 8485
# 8486  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 8297                                                              27062019
# 8298           BAG             A       350       400         360  27062019
# 8299           BAG             B       230       330         280  27062019
# 8300           BAG             A       400       500         450  27062019
# 8301           BAG             B       330       390         350  27062019
# ...            ...           ...       ...       ...         ...       ...
# 8482           BUN             A       300       400         350  27062019
# 8483           BUN             B       200       280         240  27062019
# 8484           BUN             C       120       180         140  27062019
# 8485                                                              27062019
# 8486  PACKING SIZE                    MINI      MAXI       MODAL  28062019
#
# [190 rows x 12 columns]
#         S           NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG   KG  \
# 8672    1         POTATO          1189.6
# 8673              UP(CS)                                   50   KG
# 8674                                                       50   KG
# 8675         UP/SAMSABAD                                   50   KG
# 8676                                                       50   KG
# ...   ...            ...             ...     ...          ...  ...
# 8851                                                        1   KG
# 8852   53   RADISH\n13.2
# 8853          LOC/HAR/UP                                   40  KG.
# 8854                                                       40  KG.
# 8855  NO.  COMM. & STATE         IN TONS               IN KG.
#
#       PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 8672                                                              28062019
# 8673           BAG             A       350       400         360  28062019
# 8674           BAG             B       230       330         280  28062019
# 8675           BAG             A       400       500         450  28062019
# 8676           BAG             B       330       390         350  28062019
# ...            ...           ...       ...       ...         ...       ...
# 8851         LOOSE             B         3         5           4  28062019
# 8852                                                              28062019
# 8853           BUN             A       400       450         420  28062019
# 8854           BUN             B       340       380         360  28062019
# 8855  PACKING SIZE                    MINI      MAXI       MODAL  29062019
#
# [184 rows x 12 columns]
#        S        NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG   KG PACKING_SIZE  \
# 9044   1      POTATO          1128.8
# 9045          UP(CS)                                   50   KG          BAG
# 9046                                                   50   KG          BAG
# 9047        PUN/ HAR                                   50   KG          BAG
# 9048                                                   50   KG          BAG
# ...   ..         ...             ...     ...          ...  ...          ...
# 9218                                                    1   KG        LOOSE
# 9219  53      RADISH             8.9
# 9220      LOC/HAR/UP                                   40  KG.          BUN
# 9221                                                   40  KG.          BUN
# 9222                                                   40  KG.          BUN
#
#      TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 9044                                                29062019
# 9045             A       380       450         400  29062019
# 9046             B       300       360         325  29062019
# 9047             A       240       350         300  29062019
# 9048             B       150       225         180  29062019
# ...            ...       ...       ...         ...       ...
# 9218             B         3         5           4  29062019
# 9219                                                29062019
# 9220             A       400       450         420  29062019
# 9221             B       340       380         360  29062019
# 9222             C       200       280         240  29062019
#
# [179 rows x 12 columns]

# %%
df_fruits
# Out:
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 0      1              APPLE           274.4
# 1         HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 2                                                                 10  KG.
# 3                                                                 25  KG.
# 4                                                                 25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 9039  27        WATER MELON           366.9
# 9040                 UP/RAJ                                        1   KG
# 9041                                                               1   KG
# 9042
# 9043                                                      VEGETABLES
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 0                                                                01062019
# 1           C.BOX             A       800       900         850  01062019
# 2           C.BOX             B       700       780         740  01062019
# 3           C.BOX             A      2000      2200        2100  01062019
# 4           C.BOX             B      1400      1900        1600  01062019
# ...           ...           ...       ...       ...         ...       ...
# 9039                                                             29062019
# 9040        LOOSE             A         6         7           6  29062019
# 9041        LOOSE             B         4         5           5  29062019
# 9042                                                             29062019
# 9043                                                             29062019
#
# [4909 rows x 12 columns]

# %% [markdown]
# indexNames = df_fruits[ df_fruits['WEIGHT_IN_KG'] == 'VEGETABLES' ].index
# df_fruits.drop(indexNames , inplace=True)

# %%
indexNames = df_fruits[df_fruits['WEIGHT_IN_KG'] == 'VEGETABLES'].index
df_fruits.drop(indexNames, inplace=True)

# %%
df_fruits
# Out:
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 0      1              APPLE           274.4
# 1         HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 2                                                                 10  KG.
# 3                                                                 25  KG.
# 4                                                                 25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 9038                  UP/HR                                      100  KG.
# 9039  27        WATER MELON           366.9
# 9040                 UP/RAJ                                        1   KG
# 9041                                                               1   KG
# 9042
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 0                                                                01062019
# 1           C.BOX             A       800       900         850  01062019
# 2           C.BOX             B       700       780         740  01062019
# 3           C.BOX             A      2000      2200        2100  01062019
# 4           C.BOX             B      1400      1900        1600  01062019
# ...           ...           ...       ...       ...         ...       ...
# 9038        LOOSE                     800       900         850  29062019
# 9039                                                             29062019
# 9040        LOOSE             A         6         7           6  29062019
# 9041        LOOSE             B         4         5           5  29062019
# 9042                                                             29062019
#
# [4884 rows x 12 columns]

# %%
drops = df_vegetables[df_vegetables['PACKING_SIZE'] == 'PACKING'].index
df_vegetables.drop(drops, inplace=True)
df_vegetables
# Out:
#        S         NAME ARRIVAL_IN_TONS VARIETY WEIGHT_IN_KG   KG PACKING_SIZE  \
# 191    1       POTATO          1059.5
# 192            UP(CS)                                   50   KG          BAG
# 193                                                     50   KG          BAG
# 194       UP/SAMSABAD                                   50   KG          BAG
# 195                                                     50   KG          BAG
# ...   ..          ...             ...     ...          ...  ...          ...
# 9218                                                     1   KG        LOOSE
# 9219  53       RADISH             8.9
# 9220       LOC/HAR/UP                                   40  KG.          BUN
# 9221                                                    40  KG.          BUN
# 9222                                                    40  KG.          BUN
#
#      TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 191                                                 01062019
# 192              A       400       460         425  01062019
# 193              B       200       350         300  01062019
# 194              A       350       450         375  01062019
# 195              B       290       340         300  01062019
# ...            ...       ...       ...         ...       ...
# 9218             B         3         5           4  29062019
# 9219                                                29062019
# 9220             A       400       450         420  29062019
# 9221             B       340       380         360  29062019
# 9222             C       200       280         240  29062019
#
# [4314 rows x 12 columns]

# %%
df_fruits
# Out:
#        S               NAME ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG   KG  \
# 0      1              APPLE           274.4
# 1         HPS/KINNAUR/ (CS)                  ROYAL DEL.           10  KG.
# 2                                                                 10  KG.
# 3                                                                 25  KG.
# 4                                                                 25  KG.
# ...   ..                ...             ...         ...          ...  ...
# 9038                  UP/HR                                      100  KG.
# 9039  27        WATER MELON           366.9
# 9040                 UP/RAJ                                        1   KG
# 9041                                                               1   KG
# 9042
#
#      PACKING_SIZE TYPE_OF_GRADE MIN_PRICE MAX_PRICE MODAL_PRICE      DATE
# 0                                                                01062019
# 1           C.BOX             A       800       900         850  01062019
# 2           C.BOX             B       700       780         740  01062019
# 3           C.BOX             A      2000      2200        2100  01062019
# 4           C.BOX             B      1400      1900        1600  01062019
# ...           ...           ...       ...       ...         ...       ...
# 9038        LOOSE                     800       900         850  29062019
# 9039                                                             29062019
# 9040        LOOSE             A         6         7           6  29062019
# 9041        LOOSE             B         4         5           5  29062019
# 9042                                                             29062019
#
# [4884 rows x 12 columns]

# %%
df_fruits.to_excel("fruits_june_2019.xlsx")

# %%
df_vegetables.to_excel("veggies_june_2019.xlsx")
