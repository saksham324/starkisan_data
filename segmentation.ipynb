# %%
import pandas as pd
import sys
import numpy as np
np.set_printoptions(threshold=sys.maxsize)

# %%
df_fruits = pd.read_excel("fruits_june_2019.xlsx", converters={'S':str})
df_vegetables = pd.read_excel("veggies_june_2019.xlsx")

# %%
df_fruits
# Out:
#       Unnamed: 0    S               NAME  ARRIVAL_IN_TONS     VARIETY  \
# 0              0    1              APPLE            274.4         NaN
# 1              1  NaN  HPS/KINNAUR/ (CS)              NaN  ROYAL DEL.
# 2              2  NaN                NaN              NaN         NaN
# 3              3  NaN                NaN              NaN         NaN
# 4              4  NaN                NaN              NaN         NaN
# ...          ...  ...                ...              ...         ...
# 4879        9038  NaN              UP/HR              NaN         NaN
# 4880        9039   27        WATER MELON            366.9         NaN
# 4881        9040  NaN             UP/RAJ              NaN         NaN
# 4882        9041  NaN                NaN              NaN         NaN
# 4883        9042  NaN                NaN              NaN         NaN
#
#      WEIGHT_IN_KG   KG PACKING_SIZE TYPE_OF_GRADE  MIN_PRICE  MAX_PRICE  \
# ...

# %%
array_index = df_fruits['S'].to_numpy()
array_names = df_fruits['NAME'].to_numpy()
array_index_veg = df_vegetables['S'].to_numpy()
array_names_veg = df_vegetables['NAME'].to_numpy()

# %%
indices = []
indices_veg =[]
names = []
names_veg = []

# %%
for k in range(len(array_index)):
    if isinstance(array_index[k], str):
        indices.append(array_index[k])
        names.append(array_index[k] + str(array_names[k]))
        
for p in range(len(array_index_veg)):
    if isinstance(array_index_veg[p], str):
        indices_veg.append(array_index_veg[p])
        names_veg.append(array_index_veg[p] + str(array_names_veg[p]))

# %%
names
# Out:
# ['1APPLE',
#  '2APRICOT',
#  '3ALMOND',
#  '4AMROOD',
#  '5POMEGRANATE',
#  '6BANANA',
#  '7BAILGIRI',
#  '8R.BER',
#  '9CHERRY',
#  '10CHIKOO',
#  '11COCONUT',
#  '12G.COCONUT',
#  '13FIG',
#  '14GRAPES',
#  '15JAMUN',
#  '16LEECHI',
#  '18MELON',
#  '19MELON/SARDA(South)(Yellow)',
#  '20MANGO',
#  '21MOSAMBI',
#  '22PAPAYA',
#  '23PEACH(AADU)',
#  '24PINE.APPLE',
#  '25PHALSA',
#  '26PLUM',
#  '27SUGERCANE',
#  '28WATER MELON',
#  '1APPLE',
#  '2APRICOT',
#  '3ALMOND',
#  '4AMROOD',
#  '5POMEGRANATE',
#  '6BANANA',
#  '7BAILGIRI',
#  '8R.BER',
#  '9CHERRY',
#  '10CHIKOO',
#  '11COCONUT',
#  '12G.COCONUT',
#  '13FIG',
#  '14GRAPES',
#  '15JAMUN',
#  '16LEECHI',
#  '18MELON',
#  '19MELON/SARDA(South)(Yellow)',
#  '20MANGO',
#  '21MOSAMBI',
#  '22PAPAYA',
#  '23PEACH(AADU)',
#  '24PINE.APPLE',
#  '25PHALSA',
#  '26PLUM',
#  '27SUGERCANE',
#  '28WATER MELON',
#  '1APPLE',
#  '2APRICOT',
#  '3ALMOND',
#  '4AMROOD',
#  '5POMEGRANATE',
#  '6BANANA',
#  '7BAILGIRI',
#  '8R.BER',
# ...

# %%
names_veg
# Out:
# ['1POTATO',
#  '2AMLA',
#  '3ARVI',
#  '4ARVI LEAVES',
#  '5BABYCORN',
#  '6R. BANANA',
#  '7BEANS',
#  '8BITTER GOURD',
#  '9BHUTTA',
#  '10BRINJAL',
#  '11BROKLI',
#  '12CABBAGE',
#  '13CHIRCHINDA',
#  '14CHUKANDER',
#  '15CARROT',
#  '16CAULIFLOWER',
#  '17CHOLAI',
#  '18CUCUMBER',
#  '19GAWAR',
#  '20GARLIC',
#  '21G.GARLIC',
#  '22G.CORIANDER',
#  '23M.GINGER',
#  '24GOURD',
#  '25GALGAL',
#  '26HALDI GREEN',
#  '27ICEBERG',
#  '28JIMIKAND',
#  '29JUGNI',
#  '30KACHRI',
#  '31KAKRI',
#  '32K.KAKRI',
#  '33KAKRONDA',
#  '34KAKORA',
#  '35KATHAL',
#  '36KHATTA',
#  '37KULFA',
#  '38KUNDRU',
#  '39KACHALU',
#  '40LADY FINGER',
#  '41LEHSUA',
#  '42LEMON',
#  '43G.LOBHIYA',
#  '44R.MANGO',
#  '45METHI',
#  '46MINT',
#  '47M.CHILLI',
#  '48MUSHROOM',
#  '49ONION',
#  '50G.ONION',
#  '51PEAS',
#  '52PERMAL',
#  '53PHUEE',
#  '54PUMPKIN',
#  '55RADISH\n19.5',
#  'NO.COMM. & STATE',
#  '1POTATO',
#  '2AMLA',
#  '3ARVI',
#  '4ARVI LEAVES',
#  '5BABYCORN',
#  '6R. BANANA',
#  '7BEANS',
# ...

# %%
dff_main = df_fruits.index[df_fruits['S'] + df_fruits['NAME'] == names[1]]
dff_veg = df_vegetables.index[df_vegetables['S'] + df_vegetables['NAME'] == names_veg[1]]

# %%
main_indices = {}
main_indices_veg = {}

# %%
for item in names:
    if item not in main_indices:
        main_indices[item] = df_fruits.index[df_fruits['S'] + df_fruits['NAME'] == item]     
        
for veg in names_veg:
    if veg not in main_indices_veg:
        main_indices_veg[veg] = df_vegetables.index[df_vegetables['S'] + df_vegetables['NAME'] == veg]

# %%
main_indices_veg
# Out:
# {'1POTATO': Int64Index([   0,  178,  351,  521,  694,  864, 1034, 1207, 1373, 1535, 1694,
#              1853, 2012, 2183, 2350, 2520, 2691, 2862, 3032, 3210, 3385, 3571,
#              3761, 3951, 4135],
#             dtype='int64'),
#  '2AMLA': Int64Index([  14,  192,  365,  535,  708,  878, 1048, 1221, 1387, 1549, 1708,
#              1867, 2026, 2197, 2364, 2534, 2703, 2874, 3044, 3222, 3397, 3583,
#              3775, 3965, 4147],
#             dtype='int64'),
#  '3ARVI': Int64Index([  17,  195,  368,  538,  711,  881, 1051, 1224, 1390, 1552, 1711,
#              1870, 2029, 2200, 2367, 2537, 2706, 2877, 3047, 3225, 3400, 3586,
#              3778, 3968, 4150],
#             dtype='int64'),
#  '4ARVI LEAVES': Int64Index([  20,  198,  371,  541,  714,  884, 1054, 1227, 1393, 1555, 1714,
#              1873, 2032, 2203, 2370, 2540, 2709, 2880, 3050, 3228, 3403, 3589,
#              3781, 3971, 4153],
#             dtype='int64'),
# ...

# %%
df_fruits[0:16]
# Out:
#     Unnamed: 0    S            NAME  ARRIVAL_IN_TONS     VARIETY WEIGHT_IN_KG  \
# 0            0    1           APPLE             38.8         NaN          NaN
# 1            1  NaN  HP/KINNAUR(CS)              NaN  ROYAL DEL.           10
# 2            2  NaN             NaN              NaN         NaN           10
# 3            3  NaN             NaN              NaN         NaN           10
# 4            4  NaN     HPS/UTK(CS)              NaN  ROYAL DEL.           10
# 5            5  NaN             NaN              NaN         NaN           10
# 6            6  NaN             NaN              NaN         NaN           10
# 7            7  NaN       KULLU(CS)              NaN  ROYAL DEL.           10
# 8            8  NaN             NaN              NaN         NaN           10
# 9            9  NaN             NaN              NaN         NaN           10
# 10          10  NaN  J&K/SOPORE(CS)              NaN   DELICIOUS           16
# ...

# %%
df_fruits[244:260]
# Out:
#      Unnamed: 0    S            NAME  ARRIVAL_IN_TONS     VARIETY  \
# 244         448    1           APPLE            131.2         NaN
# 245         449  NaN  HP/KINNAUR(CS)              NaN  ROYAL DEL.
# 246         450  NaN             NaN              NaN         NaN
# 247         451  NaN             NaN              NaN         NaN
# 248         452  NaN     HPS/UTK(CS)              NaN  ROYAL DEL.
# 249         453  NaN             NaN              NaN         NaN
# 250         454  NaN             NaN              NaN         NaN
# 251         455  NaN       KULLU(CS)              NaN  ROYAL DEL.
# 252         456  NaN             NaN              NaN         NaN
# 253         457  NaN             NaN              NaN         NaN
# 254         458  NaN  J&K/SOPORE(CS)              NaN   DELICIOUS
# 255         459  NaN             NaN              NaN         NaN
# 256         460  NaN             NaN              NaN         NaN
# ...

# %%
df_list = {}
df_list_veg = {}

# %%
for l in range(len(names) - 1):
    if names[l] not in df_list:
        if len(main_indices[names[l]]) == len(main_indices[names[l+1]]):
            for n in range(len(main_indices[names[l]])):
                df_list[names[l]] =[ df_fruits[main_indices[names[l]][n]: main_indices[names[l+1]][n]]]
    else:
        if len(main_indices[names[l]]) == len(main_indices[names[l+1]]):
            for n in range(len(main_indices[names[l]])):
                df_list[names[l]].append(df_fruits[main_indices[names[l]][n] : main_indices[names[l+1]][n]])    

for v in range(len(names_veg) - 1):
    if names_veg[v] not in df_list_veg:
        if len(main_indices_veg[names_veg[v]]) == len(main_indices_veg[names_veg[v+1]]):
            for n in range(len(main_indices_veg[names_veg[v]])):
                df_list_veg[names_veg[v]] =[ df_vegetables[main_indices_veg[names_veg[v]][n]: main_indices_veg[names_veg[v+1]][n]]]
    else:
        if len(main_indices_veg[names_veg[v]]) == len(main_indices_veg[names_veg[v+1]]):
            for n in range(len(main_indices_veg[names_veg[v]])):
                df_list_veg[names_veg[v]].append(df_vegetables[main_indices_veg[names_veg[v]][n] : main_indices_veg[names_veg[v+1]][n]])

# %%
main_indices
# Out:
# {'1APPLE': Int64Index([   0,  190,  385,  583,  778,  976, 1174, 1369, 1571, 1777, 1986,
#              2195, 2404, 2601, 2802, 3000, 3197, 3394, 3592, 3782, 3975, 4157,
#              4335, 4513, 4697],
#             dtype='int64'),
#  '2APRICOT': Int64Index([  15,  205,  400,  598,  793,  991, 1189, 1384, 1586, 1792, 2001,
#              2210, 2419, 2616, 2817, 3015, 3212, 3409, 3607, 3797, 3990, 4172,
#              4350, 4522, 4706],
#             dtype='int64'),
#  '3ALMOND': Int64Index([  23,  213,  408,  606,  801,  999, 1197, 1392, 1594, 1800, 2009,
#              2218, 2427, 2624, 2825, 3023, 3220, 3417, 3615, 3805, 3993, 4175,
#              4353, 4525, 4709],
#             dtype='int64'),
#  '4AMROOD': Int64Index([  28,  218,  413,  611,  806, 1004, 1202, 1397, 1601, 1807, 2016,
#              2225, 2434, 2631, 2832, 3030, 3227, 3424, 3622, 3812, 4000, 4182,
#              4360, 4532, 4716],
#             dtype='int64'),
# ...

# %%
df_list_veg['1POTATO'][26]
# len(main_indices_veg['24GOURD'])
# Out:
#       Unnamed: 0    S          NAME  ARRIVAL_IN_TONS     VARIETY  \
# 3594        8865    1        POTATO           1326.1         NaN
# 3595        8866  NaN    UP/AGRA/CS              NaN         NaN
# 3596        8867  NaN           NaN              NaN         NaN
# 3597        8868  NaN       PUN/GUJ              NaN        L.R.
# 3598        8869  NaN           NaN              NaN         NaN
# 3599        8870  NaN  HPS/HALDWANI              NaN         NaN
# 3600        8871  NaN           NaN              NaN         NaN
# 3601        8872  NaN            UP              NaN  GOLI/GULLA
#
#       WEIGHT_IN_KG      KG  PACKING_SIZE TYPE_OF_GRADE  MIN_PRICE  MAX_PRICE  \
# 3594           NaN     NaN           NaN           NaN        NaN        NaN
# 3595          50.0  KG BAG           NaN             A      260.0      340.0
# 3596          50.0  KG BAG           NaN             B      200.0      250.0
# ...

# %%
list_fruit = []
list_veg = []
for key in df_list:
    df = df_list[key][0]
    for k in range(1, len(main_indices[key])):
        df1 = df_list[key][k]
        df = pd.concat([df, df1], axis=0)
    list_fruit.append(key.replace("/", "_"))
    features = ['MIN_PRICE', 'MAX_PRICE', 'MODAL_PRICE']
    df[features].astype('float')
    df.to_excel("fruits/2018/" + key[1:].replace("/", "_") +"_june_2018.xlsx")
    

for veg in df_list_veg:
    df_veg = df_list_veg[veg][0]
    for p in range(1, len(main_indices_veg[veg])):
        print(veg)
        df1 = df_list_veg[veg][p]
        df_veg = pd.concat([df_veg, df1], axis=0) 
    features = ['MIN_PRICE', 'MAX_PRICE', 'MODAL_PRICE']
    df_veg[features].astype('float')
    list_veg.append(veg)
    df_veg.to_excel("veggies/2018/" + veg[1:] +"_june_2018.xlsx")
# Out:
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 1POTATO
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 2AMLA
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 3ARVI
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 4ARVI LEAVES
# 5BABYCORN
# ...

# %%
df_apple = []
[df_apple.append(x) for x in df_list['1APPLE'] if x not in df_apple]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-4150445ba2ee> in <module>
#       1 df_apple = []
# ----> 2 [df_apple.append(x) for x in df_list['1APPLE'] if x not in df_apple]
#
# <ipython-input-27-4150445ba2ee> in <listcomp>(.0)
#       1 df_apple = []
# ----> 2 [df_apple.append(x) for x in df_list['1APPLE'] if x not in df_apple]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other)
#     773             if not self._indexed_same(other):
#     774                 raise ValueError(
# --> 775                     "Can only compare identically-labeled DataFrame objects"
#     776                 )
#     777             new_data = dispatch_to_series(self, other, op, str_rep)
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %%
df_fruits[dff_main[1]:dff_main[2]]
# Out:
#      Unnamed: 0    S                         NAME  ARRIVAL_IN_TONS    VARIETY  \
# 260         464    2                       AMROOD              2.2        NaN
# 261         465  NaN  MP/CHATTISGARH/RAIPUR/AP/WB              NaN        NaN
# 262         466  NaN                          NaN              NaN        NaN
# 263         467  NaN                          NaN              NaN        NaN
# 264         468    3                       ALMOND              NaN        NaN
# ..          ...  ...                          ...              ...        ...
# 496         907  NaN                          NaN              NaN        NaN
# 497         908  NaN                          NaN              NaN        NaN
# 498         909  NaN                  SHOPIAN(CS)              NaN  DELICIOUS
# 499         910  NaN                          NaN              NaN        NaN
# 500         911  NaN                          NaN              NaN        NaN
#
# ...

# %%
list =[]
for key in main_indices:
    list.append(key)

# %%
list_fruit
# Out:
# ['1APPLE',
#  '2APRICOT',
#  '3ALMOND',
#  '4AMROOD',
#  '8R.BER',
#  '9CHERRY',
#  '10CHIKOO',
#  '11COCONUT',
#  '14GRAPES',
#  '15JAMUN',
#  '18MELON',
#  '19MELON_SARDA(South)(Yellow)',
#  '20MANGO',
#  '21MOSAMBI',
#  '22PAPAYA',
#  '25PHALSA',
#  '26PLUM',
#  '27SUGERCANE',
#  '25PLUM',
#  '26SUGERCANE',
#  '9R.BER',
#  '10CHERRY',
#  '11CHIKOO',
#  '12COCONUT',
#  '17MELON',
#  '18MELON_SARDA(South)(Yellow)',
#  '19MANGO',
#  '20MOSAMBI',
#  '21PAPAYA']

# %%
list_veg
# Out:
# ['1POTATO',
#  '2AMLA',
#  '3ARVI',
#  '4ARVI LEAVES',
#  '5BABYCORN',
#  '7BEANS',
#  '8BITTER GOURD',
#  '9BHUTTA',
#  '10BRINJAL',
#  '11BROKLI',
#  '12CABBAGE',
#  '13CHIRCHINDA',
#  '14CHUKANDER',
#  '15CARROT',
#  '16CAULIFLOWER',
#  '17CHOLAI',
#  '18CUCUMBER',
#  '19GAWAR',
#  '22G.CORIANDER',
#  '23M.GINGER',
#  '26HALDI GREEN',
#  '27ICEBERG',
#  '28JIMIKAND',
#  '29JUGNI',
#  '30KACHRI',
#  '31KAKRI',
#  '32K.KAKRI',
#  '33KAKRONDA',
#  '34KAKORA',
#  '36KHATTA',
#  '37KULFA',
#  '38KUNDRU',
#  '39KACHALU',
#  '40LADY FINGER',
#  '41LEHSUA',
#  '42LEMON',
#  '43G.LOBHIYA',
#  '44R.MANGO',
#  '45METHI',
#  '46MINT',
#  '47M.CHILLI',
#  '48MUSHROOM',
#  '49ONION',
#  '21G.CORIANDER',
#  '22M.GINGER',
#  '23GOURD',
#  '24GALGAL',
#  '25HALDI GREEN',
#  '26ICEBERG',
#  '27JIMIKAND',
#  '28JUGNI',
#  '29KACHRI',
#  '30KAKRI',
#  '31K.KAKRI',
#  '32KAKRONDA',
#  '33KAKORA',
#  '36KULFA',
#  '37KUNDRU',
#  '40LEHSUA',
#  '41LEMON',
#  '42G.LOBHIYA',
#  '44METHI',
#  '45MINT',
# ...
